# %% [markdown]
# ## Statistical inference

# %% [markdown]
# ### P-value

# %% [markdown]
# Throw a coin 20 times, and calculate the p-value for the result obtained assuming the null hypothesis that the coin is fair.
#
# Assuming a uniform prior on heads probability plot the posterior distribution.
#
# How many times you would have to throw the dice to get a test with power 95% assuming that the coin has 0.6 probabaility for coming up head and significance level of 5%.

# %% [markdown]
# ### Bayes classifier

# %% [markdown]
# Please assume that average female height is a normally distributed random variable with mean of 68" (inches) standard deviation of 3.5". For male heights this is 70" and 4" respectively.
#
# 1. Assuming that women makeup 25% of the population at our faculty, calculate and plot the probability P(F|h) that given height a person is a women.
# 2. If we classify a person as women when P(F|h)>1/2 what is True Positives Rate and False Positives Rate?
# 3. Calculate and plot the whole ROC curve this classifier.
# 4. Assuming that "cost" od mistaking men for women is 2 and mistaking women for men is 3 what is the best classifier?

# %% [markdown]
# ## Hypothesis testing

# %% [markdown]
# Hypothesis testing
# Using Welch's t-test check if the two samples from files sample_1.txt and sample_1.txt were drawn from the distributions with equal means.
#
# Knowing that the sample 1 comes from normal distribution with mean 0.5 and std 1 and sample 2 has mean 0.75 and sigma 0.75 calculate the power of the test.
#
# Assuming samples of the same size how big this size must be to obtain 90% power with significance level of 1%?

# %%
from scipy.stats import binom
import random

# flips = [5, 5, 6, 2, 7, 2, 5, 6, 6, 7, 6, 6, 4, 8]
# extreme_flips = [flips]
# print(len(flips))
# [o, o, o, o, o, o, o, o, r, r]
def get_prob_for(flip_count, head_prob, head_count):
    result = 1
    tail_prob = 1 - head_prob
    tail_count = flip_count - head_count
    for i in range(head_count):
        result *= head_prob
    for i in range(tail_count):
        result *= tail_prob
    return result

def get_count_for(flip_count, head_count):
    result = silnia(flip_count) / (silnia(head_count)*silnia(flip_count-head_count))
    return result
#     return binom(flip_count, head_count)

    
#     result = 1
#     for i in (head_count, flip_count+1):
#         result *= i
#     return result

def silnia(k):
    result = 1
    for i in range(1,k+1):
        result *= i
    return result

def get_p_value_for(flip_count, head_count, head_prob):
    if flip_count == head_count*2:
        return 1
    if(head_count < flip_count/2):
        head_count = flip_count - head_count
    result = 0
    for i in range(head_count, flip_count+1):
        result += get_prob_for(flip_count, head_prob, i) * get_count_for(flip_count, i)
    return 2*result

def get_sample_data_with_prob(count, prob):
    result = 0
    for i in range(count):
        if random.random() < prob:
            result += 1
    return result
    

flip_count = 10
head_count = 8
head_prob = 0.5
p_value = get_p_value_for(flip_count, head_count, head_prob)
print(p_value)
# Out:
# 0.109375

# %%
p_value1 = get_p_value_for(10, 8, 0.5)
p_value2 = get_p_value_for(10, 2, 0.5)
print(p_value1)
print(p_value2)
# Out:
# 0.109375
# 0.109375

# %%
alpha = 0.05
head_prob = 0.6
test_power = 1000
for flip_count in range(5, 500):
    under_alpha_count = 0
    for i in range(test_power):
        head_count = get_sample_data_with_prob(flip_count, head_prob)
        p_value = get_p_value_for(flip_count, head_count, 0.5)
        if p_value < alpha:
#             print("WARNING")
            under_alpha_count += 1
    print("FLIP COUNT: "+str(flip_count)+", for "+str(test_power)+" attempts, " + str(under_alpha_count)+" were under p_value")    
#     print("FC: "+str(flip_count)+"\tHC: "+str(head_count)+"\tPV: "+str(p_value))
# Out:
# FLIP COUNT: 5, for 1000 attempts, 0 were under p_value
# FLIP COUNT: 6, for 1000 attempts, 54 were under p_value
# FLIP COUNT: 7, for 1000 attempts, 33 were under p_value
# FLIP COUNT: 8, for 1000 attempts, 8 were under p_value
# FLIP COUNT: 9, for 1000 attempts, 65 were under p_value
# FLIP COUNT: 10, for 1000 attempts, 47 were under p_value
# FLIP COUNT: 11, for 1000 attempts, 28 were under p_value
# FLIP COUNT: 12, for 1000 attempts, 104 were under p_value
# FLIP COUNT: 13, for 1000 attempts, 50 were under p_value
# FLIP COUNT: 14, for 1000 attempts, 44 were under p_value
# FLIP COUNT: 15, for 1000 attempts, 78 were under p_value
# FLIP COUNT: 16, for 1000 attempts, 61 were under p_value
# FLIP COUNT: 17, for 1000 attempts, 120 were under p_value
# FLIP COUNT: 18, for 1000 attempts, 91 were under p_value
# FLIP COUNT: 19, for 1000 attempts, 84 were under p_value
# FLIP COUNT: 20, for 1000 attempts, 131 were under p_value
# FLIP COUNT: 21, for 1000 attempts, 96 were under p_value
# FLIP COUNT: 22, for 1000 attempts, 77 were under p_value
# FLIP COUNT: 23, for 1000 attempts, 111 were under p_value
# FLIP COUNT: 24, for 1000 attempts, 99 were under p_value
# FLIP COUNT: 25, for 1000 attempts, 150 were under p_value
# FLIP COUNT: 26, for 1000 attempts, 120 were under p_value
# FLIP COUNT: 27, for 1000 attempts, 101 were under p_value
# FLIP COUNT: 28, for 1000 attempts, 133 were under p_value
# FLIP COUNT: 29, for 1000 attempts, 131 were under p_value
# FLIP COUNT: 30, for 1000 attempts, 181 were under p_value
# FLIP COUNT: 31, for 1000 attempts, 131 were under p_value
# FLIP COUNT: 32, for 1000 attempts, 113 were under p_value
# FLIP COUNT: 33, for 1000 attempts, 182 were under p_value
# FLIP COUNT: 34, for 1000 attempts, 150 were under p_value
# FLIP COUNT: 35, for 1000 attempts, 178 were under p_value
# FLIP COUNT: 36, for 1000 attempts, 178 were under p_value
# FLIP COUNT: 37, for 1000 attempts, 222 were under p_value
# FLIP COUNT: 38, for 1000 attempts, 178 were under p_value
# FLIP COUNT: 39, for 1000 attempts, 156 were under p_value
# FLIP COUNT: 40, for 1000 attempts, 209 were under p_value
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-fb8c98f9550c> in <module>
#       6     for i in range(test_power):
#       7         head_count = get_sample_data_with_prob(flip_count, head_prob)
# ----> 8         p_value = get_p_value_for(flip_count, head_count, 0.5)
#       9         if p_value < alpha:
#      10 #             print("WARNING")
#
# <ipython-input-1-d436aedad643> in get_p_value_for(flip_count, head_count, head_prob)
#      40     result = 0
#      41     for i in range(head_count, flip_count+1):
# ---> 42         result += get_prob_for(flip_count, head_prob, i) * get_count_for(flip_count, i)
#      43     return 2*result
#      44
#
# <ipython-input-1-d436aedad643> in get_count_for(flip_count, head_count)
#      17
#      18 def get_count_for(flip_count, head_count):
# ---> 19     result = silnia(flip_count) / (silnia(head_count)*silnia(flip_count-head_count))
#      20     return result
#      21 #     return binom(flip_count, head_count)
#
# <ipython-input-1-d436aedad643> in silnia(k)
#      29 def silnia(k):
#      30     result = 1
# ---> 31     for i in range(1,k+1):
#      32         result *= i
#      33     return result
#
# KeyboardInterrupt:

# %%
import numpy as np
def get_sample_data_with_prob(count, prob):
    result = np.random.binomial(count, prob, 1)
    return result[0]

# %%
def get_p_value_for2(flip_count, head_count_array, head_prob): 
    head_count_vector = get_array_vector(flip_count, head_count_array)
#     if flip_count == head_count*2:
#         return 1
#     result = 0
#     for i in range(head_count, flip_count+1):
#         result += get_prob_for(flip_count, head_prob, i) * get_count_for(flip_count, i)
#     return 2*result
    frequency_array = []
    tmp_result = 0
    for i in range(flip_count, int(flip_count/2), -1):
        tmp_result += get_prob_for(flip_count, head_prob, i) * get_count_for(flip_count, i)
        frequency_array.append(tmp_result*2)
    if flip_count % 2 == 0:
        frequency_array.append(1)
    result = []
    for key, count in head_count_vector:
        result.append((count, frequency_array[flip_count-key]))
#     print(result)
    return result
def get_array_vector(flip_count, head_count_array): #returns pair of key and count
    head_count_array = [flip_count - element if element*2 < flip_count else element for element in head_count_array]
    head_count_set = sorted(set(head_count_array))
    result = []
    for element in head_count_set:
        result.append((element, head_count_array.count(element)))
    return result
get_p_value_for2(7, [0,1,2,3,4,5,6,7], 0.5)
# Out:
# [(2, 1.0), (2, 0.453125), (2, 0.125), (2, 0.015625)]

# %%
alpha = 0.05
head_prob = 0.6
test_power = 1000
for flip_count in range(5, 500):
    under_alpha_count = 0
    result = 0
    p_value_vector = get_p_value_for2(flip_count, np.random.binomial(flip_count, head_prob, test_power), 0.5)
    for count, p_value in p_value_vector:
        if p_value < alpha:
            result += count
    print("FLIP COUNT: "+str(flip_count)+", for "+str(test_power)+" attempts, " + str(result)+" were under p_value")
# Out:
# FLIP COUNT: 5, for 1000 attempts, 0 were under p_value
# FLIP COUNT: 6, for 1000 attempts, 53 were under p_value
# FLIP COUNT: 7, for 1000 attempts, 25 were under p_value
# FLIP COUNT: 8, for 1000 attempts, 18 were under p_value
# FLIP COUNT: 9, for 1000 attempts, 66 were under p_value
# FLIP COUNT: 10, for 1000 attempts, 44 were under p_value
# FLIP COUNT: 11, for 1000 attempts, 33 were under p_value
# FLIP COUNT: 12, for 1000 attempts, 80 were under p_value
# FLIP COUNT: 13, for 1000 attempts, 52 were under p_value
# FLIP COUNT: 14, for 1000 attempts, 58 were under p_value
# FLIP COUNT: 15, for 1000 attempts, 108 were under p_value
# FLIP COUNT: 16, for 1000 attempts, 71 were under p_value
# FLIP COUNT: 17, for 1000 attempts, 108 were under p_value
# FLIP COUNT: 18, for 1000 attempts, 83 were under p_value
# FLIP COUNT: 19, for 1000 attempts, 73 were under p_value
# FLIP COUNT: 20, for 1000 attempts, 144 were under p_value
# FLIP COUNT: 21, for 1000 attempts, 82 were under p_value
# FLIP COUNT: 22, for 1000 attempts, 66 were under p_value
# FLIP COUNT: 23, for 1000 attempts, 122 were under p_value
# FLIP COUNT: 24, for 1000 attempts, 100 were under p_value
# FLIP COUNT: 25, for 1000 attempts, 144 were under p_value
# FLIP COUNT: 26, for 1000 attempts, 129 were under p_value
# FLIP COUNT: 27, for 1000 attempts, 97 were under p_value
# FLIP COUNT: 28, for 1000 attempts, 156 were under p_value
# FLIP COUNT: 29, for 1000 attempts, 112 were under p_value
# FLIP COUNT: 30, for 1000 attempts, 169 were under p_value
# FLIP COUNT: 31, for 1000 attempts, 133 were under p_value
# FLIP COUNT: 32, for 1000 attempts, 121 were under p_value
# FLIP COUNT: 33, for 1000 attempts, 156 were under p_value
# FLIP COUNT: 34, for 1000 attempts, 139 were under p_value
# FLIP COUNT: 35, for 1000 attempts, 196 were under p_value
# FLIP COUNT: 36, for 1000 attempts, 177 were under p_value
# FLIP COUNT: 37, for 1000 attempts, 223 were under p_value
# FLIP COUNT: 38, for 1000 attempts, 171 were under p_value
# FLIP COUNT: 39, for 1000 attempts, 149 were under p_value
# FLIP COUNT: 40, for 1000 attempts, 219 were under p_value
# FLIP COUNT: 41, for 1000 attempts, 154 were under p_value
# FLIP COUNT: 42, for 1000 attempts, 233 were under p_value
# FLIP COUNT: 43, for 1000 attempts, 198 were under p_value
# FLIP COUNT: 44, for 1000 attempts, 250 were under p_value
# FLIP COUNT: 45, for 1000 attempts, 221 were under p_value
# FLIP COUNT: 46, for 1000 attempts, 177 were under p_value
# FLIP COUNT: 47, for 1000 attempts, 245 were under p_value
# FLIP COUNT: 48, for 1000 attempts, 214 were under p_value
# FLIP COUNT: 49, for 1000 attempts, 265 were under p_value
# FLIP COUNT: 50, for 1000 attempts, 224 were under p_value
# FLIP COUNT: 51, for 1000 attempts, 291 were under p_value
# FLIP COUNT: 52, for 1000 attempts, 251 were under p_value
# FLIP COUNT: 53, for 1000 attempts, 231 were under p_value
# FLIP COUNT: 54, for 1000 attempts, 309 were under p_value
# FLIP COUNT: 55, for 1000 attempts, 231 were under p_value
# FLIP COUNT: 56, for 1000 attempts, 317 were under p_value
# FLIP COUNT: 57, for 1000 attempts, 262 were under p_value
# FLIP COUNT: 58, for 1000 attempts, 364 were under p_value
# FLIP COUNT: 59, for 1000 attempts, 293 were under p_value
# FLIP COUNT: 60, for 1000 attempts, 262 were under p_value
# FLIP COUNT: 61, for 1000 attempts, 298 were under p_value
# FLIP COUNT: 62, for 1000 attempts, 284 were under p_value
# FLIP COUNT: 63, for 1000 attempts, 337 were under p_value
# FLIP COUNT: 64, for 1000 attempts, 286 were under p_value
# FLIP COUNT: 65, for 1000 attempts, 316 were under p_value
# FLIP COUNT: 66, for 1000 attempts, 334 were under p_value
# FLIP COUNT: 67, for 1000 attempts, 364 were under p_value
# FLIP COUNT: 68, for 1000 attempts, 357 were under p_value
# FLIP COUNT: 69, for 1000 attempts, 296 were under p_value
# FLIP COUNT: 70, for 1000 attempts, 377 were under p_value
# FLIP COUNT: 71, for 1000 attempts, 333 were under p_value
# FLIP COUNT: 72, for 1000 attempts, 380 were under p_value
# FLIP COUNT: 73, for 1000 attempts, 352 were under p_value
# FLIP COUNT: 74, for 1000 attempts, 421 were under p_value
# FLIP COUNT: 75, for 1000 attempts, 353 were under p_value
# FLIP COUNT: 76, for 1000 attempts, 347 were under p_value
# FLIP COUNT: 77, for 1000 attempts, 396 were under p_value
# FLIP COUNT: 78, for 1000 attempts, 359 were under p_value
# FLIP COUNT: 79, for 1000 attempts, 397 were under p_value
# FLIP COUNT: 80, for 1000 attempts, 375 were under p_value
# FLIP COUNT: 81, for 1000 attempts, 432 were under p_value
# FLIP COUNT: 82, for 1000 attempts, 424 were under p_value
# FLIP COUNT: 83, for 1000 attempts, 445 were under p_value
# FLIP COUNT: 84, for 1000 attempts, 425 were under p_value
# FLIP COUNT: 85, for 1000 attempts, 357 were under p_value
# FLIP COUNT: 86, for 1000 attempts, 439 were under p_value
# FLIP COUNT: 87, for 1000 attempts, 359 were under p_value
# FLIP COUNT: 88, for 1000 attempts, 473 were under p_value
# FLIP COUNT: 89, for 1000 attempts, 412 were under p_value
# FLIP COUNT: 90, for 1000 attempts, 488 were under p_value
# FLIP COUNT: 91, for 1000 attempts, 414 were under p_value
# FLIP COUNT: 92, for 1000 attempts, 471 were under p_value
# FLIP COUNT: 93, for 1000 attempts, 440 were under p_value
# FLIP COUNT: 94, for 1000 attempts, 482 were under p_value
# FLIP COUNT: 95, for 1000 attempts, 463 were under p_value
# FLIP COUNT: 96, for 1000 attempts, 439 were under p_value
# FLIP COUNT: 97, for 1000 attempts, 492 were under p_value
# FLIP COUNT: 98, for 1000 attempts, 459 were under p_value
# FLIP COUNT: 99, for 1000 attempts, 464 were under p_value
# FLIP COUNT: 100, for 1000 attempts, 456 were under p_value
# FLIP COUNT: 101, for 1000 attempts, 521 were under p_value
# FLIP COUNT: 102, for 1000 attempts, 469 were under p_value
# FLIP COUNT: 103, for 1000 attempts, 507 were under p_value
# FLIP COUNT: 104, for 1000 attempts, 499 were under p_value
# FLIP COUNT: 105, for 1000 attempts, 460 were under p_value
# FLIP COUNT: 106, for 1000 attempts, 496 were under p_value
# FLIP COUNT: 107, for 1000 attempts, 461 were under p_value
# FLIP COUNT: 108, for 1000 attempts, 524 were under p_value
# FLIP COUNT: 109, for 1000 attempts, 490 were under p_value
# FLIP COUNT: 110, for 1000 attempts, 535 were under p_value
# FLIP COUNT: 111, for 1000 attempts, 523 were under p_value
# FLIP COUNT: 112, for 1000 attempts, 552 were under p_value
# FLIP COUNT: 113, for 1000 attempts, 499 were under p_value
# FLIP COUNT: 114, for 1000 attempts, 569 were under p_value
# FLIP COUNT: 115, for 1000 attempts, 544 were under p_value
# FLIP COUNT: 116, for 1000 attempts, 525 were under p_value
# FLIP COUNT: 117, for 1000 attempts, 558 were under p_value
# FLIP COUNT: 118, for 1000 attempts, 545 were under p_value
# FLIP COUNT: 119, for 1000 attempts, 561 were under p_value
# FLIP COUNT: 120, for 1000 attempts, 564 were under p_value
# FLIP COUNT: 121, for 1000 attempts, 588 were under p_value
# FLIP COUNT: 122, for 1000 attempts, 535 were under p_value
# FLIP COUNT: 123, for 1000 attempts, 591 were under p_value
# FLIP COUNT: 124, for 1000 attempts, 551 were under p_value
# FLIP COUNT: 125, for 1000 attempts, 643 were under p_value
# FLIP COUNT: 126, for 1000 attempts, 556 were under p_value
# FLIP COUNT: 127, for 1000 attempts, 555 were under p_value
# FLIP COUNT: 128, for 1000 attempts, 596 were under p_value
# FLIP COUNT: 129, for 1000 attempts, 557 were under p_value
# FLIP COUNT: 130, for 1000 attempts, 593 were under p_value
# FLIP COUNT: 131, for 1000 attempts, 603 were under p_value
# FLIP COUNT: 132, for 1000 attempts, 624 were under p_value
# FLIP COUNT: 133, for 1000 attempts, 579 were under p_value
# FLIP COUNT: 134, for 1000 attempts, 637 were under p_value
# FLIP COUNT: 135, for 1000 attempts, 600 were under p_value
# FLIP COUNT: 136, for 1000 attempts, 664 were under p_value
# FLIP COUNT: 137, for 1000 attempts, 666 were under p_value
# FLIP COUNT: 138, for 1000 attempts, 666 were under p_value
# FLIP COUNT: 139, for 1000 attempts, 611 were under p_value
# FLIP COUNT: 140, for 1000 attempts, 616 were under p_value
# FLIP COUNT: 141, for 1000 attempts, 624 were under p_value
# FLIP COUNT: 142, for 1000 attempts, 635 were under p_value
# FLIP COUNT: 143, for 1000 attempts, 656 were under p_value
# FLIP COUNT: 144, for 1000 attempts, 641 were under p_value
# FLIP COUNT: 145, for 1000 attempts, 677 were under p_value
# FLIP COUNT: 146, for 1000 attempts, 651 were under p_value
# FLIP COUNT: 147, for 1000 attempts, 680 were under p_value
# FLIP COUNT: 148, for 1000 attempts, 636 were under p_value
# FLIP COUNT: 149, for 1000 attempts, 680 were under p_value
# FLIP COUNT: 150, for 1000 attempts, 677 were under p_value
# FLIP COUNT: 151, for 1000 attempts, 624 were under p_value
# FLIP COUNT: 152, for 1000 attempts, 688 were under p_value
# FLIP COUNT: 153, for 1000 attempts, 639 were under p_value
# FLIP COUNT: 154, for 1000 attempts, 692 were under p_value
# FLIP COUNT: 155, for 1000 attempts, 662 were under p_value
# FLIP COUNT: 156, for 1000 attempts, 691 were under p_value
# FLIP COUNT: 157, for 1000 attempts, 648 were under p_value
# FLIP COUNT: 158, for 1000 attempts, 687 were under p_value
# FLIP COUNT: 159, for 1000 attempts, 708 were under p_value
# FLIP COUNT: 160, for 1000 attempts, 719 were under p_value
# FLIP COUNT: 161, for 1000 attempts, 700 were under p_value
# FLIP COUNT: 162, for 1000 attempts, 706 were under p_value
# FLIP COUNT: 163, for 1000 attempts, 688 were under p_value
# FLIP COUNT: 164, for 1000 attempts, 667 were under p_value
# FLIP COUNT: 165, for 1000 attempts, 733 were under p_value
# FLIP COUNT: 166, for 1000 attempts, 705 were under p_value
# FLIP COUNT: 167, for 1000 attempts, 720 were under p_value
# FLIP COUNT: 168, for 1000 attempts, 705 were under p_value
# FLIP COUNT: 169, for 1000 attempts, 730 were under p_value
# FLIP COUNT: 170, for 1000 attempts, 707 were under p_value
# FLIP COUNT: 171, for 1000 attempts, 757 were under p_value
# FLIP COUNT: 172, for 1000 attempts, 714 were under p_value
# FLIP COUNT: 173, for 1000 attempts, 740 were under p_value
# FLIP COUNT: 174, for 1000 attempts, 736 were under p_value
# FLIP COUNT: 175, for 1000 attempts, 800 were under p_value
# FLIP COUNT: 176, for 1000 attempts, 748 were under p_value
# FLIP COUNT: 177, for 1000 attempts, 727 were under p_value
# FLIP COUNT: 178, for 1000 attempts, 733 were under p_value
# FLIP COUNT: 179, for 1000 attempts, 725 were under p_value
# FLIP COUNT: 180, for 1000 attempts, 732 were under p_value
# FLIP COUNT: 181, for 1000 attempts, 745 were under p_value
# FLIP COUNT: 182, for 1000 attempts, 777 were under p_value
# FLIP COUNT: 183, for 1000 attempts, 731 were under p_value
# FLIP COUNT: 184, for 1000 attempts, 756 were under p_value
# FLIP COUNT: 185, for 1000 attempts, 735 were under p_value
# FLIP COUNT: 186, for 1000 attempts, 770 were under p_value
# FLIP COUNT: 187, for 1000 attempts, 756 were under p_value
# FLIP COUNT: 188, for 1000 attempts, 785 were under p_value
# FLIP COUNT: 189, for 1000 attempts, 765 were under p_value
# FLIP COUNT: 190, for 1000 attempts, 796 were under p_value
# FLIP COUNT: 191, for 1000 attempts, 778 were under p_value
# FLIP COUNT: 192, for 1000 attempts, 776 were under p_value
# FLIP COUNT: 193, for 1000 attempts, 764 were under p_value
# FLIP COUNT: 194, for 1000 attempts, 773 were under p_value
# FLIP COUNT: 195, for 1000 attempts, 788 were under p_value
# FLIP COUNT: 196, for 1000 attempts, 757 were under p_value
# FLIP COUNT: 197, for 1000 attempts, 809 were under p_value
# FLIP COUNT: 198, for 1000 attempts, 778 were under p_value
# FLIP COUNT: 199, for 1000 attempts, 825 were under p_value
# FLIP COUNT: 200, for 1000 attempts, 780 were under p_value
# FLIP COUNT: 201, for 1000 attempts, 809 were under p_value
# FLIP COUNT: 202, for 1000 attempts, 804 were under p_value
# FLIP COUNT: 203, for 1000 attempts, 799 were under p_value
# FLIP COUNT: 204, for 1000 attempts, 784 were under p_value
# FLIP COUNT: 205, for 1000 attempts, 773 were under p_value
# FLIP COUNT: 206, for 1000 attempts, 807 were under p_value
# FLIP COUNT: 207, for 1000 attempts, 786 were under p_value
# FLIP COUNT: 208, for 1000 attempts, 812 were under p_value
# FLIP COUNT: 209, for 1000 attempts, 805 were under p_value
# FLIP COUNT: 210, for 1000 attempts, 817 were under p_value
# FLIP COUNT: 211, for 1000 attempts, 794 were under p_value
# FLIP COUNT: 212, for 1000 attempts, 828 were under p_value
# FLIP COUNT: 213, for 1000 attempts, 840 were under p_value
# FLIP COUNT: 214, for 1000 attempts, 822 were under p_value
# FLIP COUNT: 215, for 1000 attempts, 837 were under p_value
# FLIP COUNT: 216, for 1000 attempts, 843 were under p_value
# FLIP COUNT: 217, for 1000 attempts, 833 were under p_value
# FLIP COUNT: 218, for 1000 attempts, 848 were under p_value
# FLIP COUNT: 219, for 1000 attempts, 840 were under p_value
# FLIP COUNT: 220, for 1000 attempts, 811 were under p_value
# FLIP COUNT: 221, for 1000 attempts, 819 were under p_value
# FLIP COUNT: 222, for 1000 attempts, 809 were under p_value
# FLIP COUNT: 223, for 1000 attempts, 836 were under p_value
# FLIP COUNT: 224, for 1000 attempts, 837 were under p_value
# FLIP COUNT: 225, for 1000 attempts, 840 were under p_value
# FLIP COUNT: 226, for 1000 attempts, 833 were under p_value
# FLIP COUNT: 227, for 1000 attempts, 856 were under p_value
# FLIP COUNT: 228, for 1000 attempts, 850 were under p_value
# FLIP COUNT: 229, for 1000 attempts, 865 were under p_value
# FLIP COUNT: 230, for 1000 attempts, 840 were under p_value
# FLIP COUNT: 231, for 1000 attempts, 868 were under p_value
# FLIP COUNT: 232, for 1000 attempts, 835 were under p_value
# FLIP COUNT: 233, for 1000 attempts, 860 were under p_value
# FLIP COUNT: 234, for 1000 attempts, 837 were under p_value
# FLIP COUNT: 235, for 1000 attempts, 831 were under p_value
# FLIP COUNT: 236, for 1000 attempts, 860 were under p_value
# FLIP COUNT: 237, for 1000 attempts, 845 were under p_value
# FLIP COUNT: 238, for 1000 attempts, 853 were under p_value
# FLIP COUNT: 239, for 1000 attempts, 837 were under p_value
# FLIP COUNT: 240, for 1000 attempts, 878 were under p_value
# FLIP COUNT: 241, for 1000 attempts, 860 were under p_value
# FLIP COUNT: 242, for 1000 attempts, 855 were under p_value
# FLIP COUNT: 243, for 1000 attempts, 853 were under p_value
# FLIP COUNT: 244, for 1000 attempts, 875 were under p_value
# FLIP COUNT: 245, for 1000 attempts, 875 were under p_value
# FLIP COUNT: 246, for 1000 attempts, 896 were under p_value
# FLIP COUNT: 247, for 1000 attempts, 857 were under p_value
# FLIP COUNT: 248, for 1000 attempts, 887 were under p_value
# FLIP COUNT: 249, for 1000 attempts, 878 were under p_value
# FLIP COUNT: 250, for 1000 attempts, 887 were under p_value
# FLIP COUNT: 251, for 1000 attempts, 886 were under p_value
# FLIP COUNT: 252, for 1000 attempts, 858 were under p_value
# FLIP COUNT: 253, for 1000 attempts, 890 were under p_value
# FLIP COUNT: 254, for 1000 attempts, 886 were under p_value
# FLIP COUNT: 255, for 1000 attempts, 892 were under p_value
# FLIP COUNT: 256, for 1000 attempts, 886 were under p_value
# FLIP COUNT: 257, for 1000 attempts, 900 were under p_value
# FLIP COUNT: 258, for 1000 attempts, 884 were under p_value
# FLIP COUNT: 259, for 1000 attempts, 894 were under p_value
# FLIP COUNT: 260, for 1000 attempts, 891 were under p_value
# FLIP COUNT: 261, for 1000 attempts, 893 were under p_value
# FLIP COUNT: 262, for 1000 attempts, 891 were under p_value
# FLIP COUNT: 263, for 1000 attempts, 883 were under p_value
# FLIP COUNT: 264, for 1000 attempts, 914 were under p_value
# FLIP COUNT: 265, for 1000 attempts, 916 were under p_value
# FLIP COUNT: 266, for 1000 attempts, 905 were under p_value
# FLIP COUNT: 267, for 1000 attempts, 901 were under p_value
# FLIP COUNT: 268, for 1000 attempts, 905 were under p_value
# FLIP COUNT: 269, for 1000 attempts, 888 were under p_value
# FLIP COUNT: 270, for 1000 attempts, 898 were under p_value
# FLIP COUNT: 271, for 1000 attempts, 888 were under p_value
# FLIP COUNT: 272, for 1000 attempts, 886 were under p_value
# FLIP COUNT: 273, for 1000 attempts, 897 were under p_value
# FLIP COUNT: 274, for 1000 attempts, 915 were under p_value
# FLIP COUNT: 275, for 1000 attempts, 894 were under p_value
# FLIP COUNT: 276, for 1000 attempts, 913 were under p_value
# FLIP COUNT: 277, for 1000 attempts, 901 were under p_value
# FLIP COUNT: 278, for 1000 attempts, 924 were under p_value
# FLIP COUNT: 279, for 1000 attempts, 910 were under p_value
# FLIP COUNT: 280, for 1000 attempts, 918 were under p_value
# FLIP COUNT: 281, for 1000 attempts, 900 were under p_value
# FLIP COUNT: 282, for 1000 attempts, 920 were under p_value
# FLIP COUNT: 283, for 1000 attempts, 917 were under p_value
# FLIP COUNT: 284, for 1000 attempts, 901 were under p_value
# FLIP COUNT: 285, for 1000 attempts, 915 were under p_value
# FLIP COUNT: 286, for 1000 attempts, 924 were under p_value
# FLIP COUNT: 287, for 1000 attempts, 938 were under p_value
# FLIP COUNT: 288, for 1000 attempts, 917 were under p_value
# FLIP COUNT: 289, for 1000 attempts, 921 were under p_value
# FLIP COUNT: 290, for 1000 attempts, 921 were under p_value
# FLIP COUNT: 291, for 1000 attempts, 921 were under p_value
# FLIP COUNT: 292, for 1000 attempts, 917 were under p_value
# FLIP COUNT: 293, for 1000 attempts, 924 were under p_value
# FLIP COUNT: 294, for 1000 attempts, 933 were under p_value
# FLIP COUNT: 295, for 1000 attempts, 928 were under p_value
# FLIP COUNT: 296, for 1000 attempts, 919 were under p_value
# FLIP COUNT: 297, for 1000 attempts, 940 were under p_value
# FLIP COUNT: 298, for 1000 attempts, 930 were under p_value
# FLIP COUNT: 299, for 1000 attempts, 943 were under p_value
# FLIP COUNT: 300, for 1000 attempts, 928 were under p_value
# FLIP COUNT: 301, for 1000 attempts, 945 were under p_value
# FLIP COUNT: 302, for 1000 attempts, 933 were under p_value
# FLIP COUNT: 303, for 1000 attempts, 915 were under p_value
# FLIP COUNT: 304, for 1000 attempts, 939 were under p_value
# FLIP COUNT: 305, for 1000 attempts, 917 were under p_value
# FLIP COUNT: 306, for 1000 attempts, 933 were under p_value
# FLIP COUNT: 307, for 1000 attempts, 938 were under p_value
# FLIP COUNT: 308, for 1000 attempts, 946 were under p_value
# FLIP COUNT: 309, for 1000 attempts, 954 were under p_value
# FLIP COUNT: 310, for 1000 attempts, 944 were under p_value
# FLIP COUNT: 311, for 1000 attempts, 928 were under p_value
# FLIP COUNT: 312, for 1000 attempts, 949 were under p_value
# FLIP COUNT: 313, for 1000 attempts, 937 were under p_value
# FLIP COUNT: 314, for 1000 attempts, 952 were under p_value
# FLIP COUNT: 315, for 1000 attempts, 940 were under p_value
# FLIP COUNT: 316, for 1000 attempts, 931 were under p_value
# FLIP COUNT: 317, for 1000 attempts, 950 were under p_value
# FLIP COUNT: 318, for 1000 attempts, 950 were under p_value
# FLIP COUNT: 319, for 1000 attempts, 938 were under p_value
# FLIP COUNT: 320, for 1000 attempts, 939 were under p_value
# FLIP COUNT: 321, for 1000 attempts, 940 were under p_value
# FLIP COUNT: 322, for 1000 attempts, 947 were under p_value
# FLIP COUNT: 323, for 1000 attempts, 945 were under p_value
# FLIP COUNT: 324, for 1000 attempts, 944 were under p_value
# FLIP COUNT: 325, for 1000 attempts, 948 were under p_value
# FLIP COUNT: 326, for 1000 attempts, 949 were under p_value
# FLIP COUNT: 327, for 1000 attempts, 957 were under p_value
# FLIP COUNT: 328, for 1000 attempts, 940 were under p_value
# FLIP COUNT: 329, for 1000 attempts, 958 were under p_value
# FLIP COUNT: 330, for 1000 attempts, 951 were under p_value
# FLIP COUNT: 331, for 1000 attempts, 942 were under p_value
# FLIP COUNT: 332, for 1000 attempts, 954 were under p_value
# FLIP COUNT: 333, for 1000 attempts, 973 were under p_value
# FLIP COUNT: 334, for 1000 attempts, 947 were under p_value
# FLIP COUNT: 335, for 1000 attempts, 947 were under p_value
# FLIP COUNT: 336, for 1000 attempts, 961 were under p_value
# FLIP COUNT: 337, for 1000 attempts, 962 were under p_value
# FLIP COUNT: 338, for 1000 attempts, 956 were under p_value
# FLIP COUNT: 339, for 1000 attempts, 949 were under p_value
# FLIP COUNT: 340, for 1000 attempts, 946 were under p_value
# FLIP COUNT: 341, for 1000 attempts, 948 were under p_value
# FLIP COUNT: 342, for 1000 attempts, 962 were under p_value
# FLIP COUNT: 343, for 1000 attempts, 955 were under p_value
# FLIP COUNT: 344, for 1000 attempts, 959 were under p_value
# FLIP COUNT: 345, for 1000 attempts, 948 were under p_value
# FLIP COUNT: 346, for 1000 attempts, 953 were under p_value
# FLIP COUNT: 347, for 1000 attempts, 954 were under p_value
# FLIP COUNT: 348, for 1000 attempts, 959 were under p_value
# FLIP COUNT: 349, for 1000 attempts, 963 were under p_value
# FLIP COUNT: 350, for 1000 attempts, 964 were under p_value
# FLIP COUNT: 351, for 1000 attempts, 965 were under p_value
# FLIP COUNT: 352, for 1000 attempts, 963 were under p_value
# FLIP COUNT: 353, for 1000 attempts, 959 were under p_value
# FLIP COUNT: 354, for 1000 attempts, 962 were under p_value
# FLIP COUNT: 355, for 1000 attempts, 973 were under p_value
# FLIP COUNT: 356, for 1000 attempts, 969 were under p_value
# FLIP COUNT: 357, for 1000 attempts, 961 were under p_value
# FLIP COUNT: 358, for 1000 attempts, 964 were under p_value
# FLIP COUNT: 359, for 1000 attempts, 963 were under p_value
# FLIP COUNT: 360, for 1000 attempts, 972 were under p_value
# FLIP COUNT: 361, for 1000 attempts, 976 were under p_value
# FLIP COUNT: 362, for 1000 attempts, 960 were under p_value
# FLIP COUNT: 363, for 1000 attempts, 958 were under p_value
# FLIP COUNT: 364, for 1000 attempts, 959 were under p_value
# FLIP COUNT: 365, for 1000 attempts, 969 were under p_value
# FLIP COUNT: 366, for 1000 attempts, 964 were under p_value
# FLIP COUNT: 367, for 1000 attempts, 966 were under p_value
# FLIP COUNT: 368, for 1000 attempts, 963 were under p_value
# FLIP COUNT: 369, for 1000 attempts, 962 were under p_value
# FLIP COUNT: 370, for 1000 attempts, 968 were under p_value
# FLIP COUNT: 371, for 1000 attempts, 959 were under p_value
# FLIP COUNT: 372, for 1000 attempts, 974 were under p_value
# FLIP COUNT: 373, for 1000 attempts, 959 were under p_value
# FLIP COUNT: 374, for 1000 attempts, 979 were under p_value
# FLIP COUNT: 375, for 1000 attempts, 969 were under p_value
# FLIP COUNT: 376, for 1000 attempts, 968 were under p_value
# FLIP COUNT: 377, for 1000 attempts, 968 were under p_value
# FLIP COUNT: 378, for 1000 attempts, 973 were under p_value
# FLIP COUNT: 379, for 1000 attempts, 975 were under p_value
# FLIP COUNT: 380, for 1000 attempts, 965 were under p_value
# FLIP COUNT: 381, for 1000 attempts, 979 were under p_value
# FLIP COUNT: 382, for 1000 attempts, 970 were under p_value
# FLIP COUNT: 383, for 1000 attempts, 981 were under p_value
# FLIP COUNT: 384, for 1000 attempts, 974 were under p_value
# FLIP COUNT: 385, for 1000 attempts, 972 were under p_value
# FLIP COUNT: 386, for 1000 attempts, 982 were under p_value
# FLIP COUNT: 387, for 1000 attempts, 968 were under p_value
# FLIP COUNT: 388, for 1000 attempts, 976 were under p_value
# FLIP COUNT: 389, for 1000 attempts, 972 were under p_value
# FLIP COUNT: 390, for 1000 attempts, 981 were under p_value
# FLIP COUNT: 391, for 1000 attempts, 980 were under p_value
# FLIP COUNT: 392, for 1000 attempts, 986 were under p_value
# FLIP COUNT: 393, for 1000 attempts, 982 were under p_value
# FLIP COUNT: 394, for 1000 attempts, 983 were under p_value
# FLIP COUNT: 395, for 1000 attempts, 978 were under p_value
# FLIP COUNT: 396, for 1000 attempts, 970 were under p_value
# FLIP COUNT: 397, for 1000 attempts, 973 were under p_value
# FLIP COUNT: 398, for 1000 attempts, 969 were under p_value
# FLIP COUNT: 399, for 1000 attempts, 974 were under p_value
# FLIP COUNT: 400, for 1000 attempts, 978 were under p_value
# FLIP COUNT: 401, for 1000 attempts, 985 were under p_value
# FLIP COUNT: 402, for 1000 attempts, 978 were under p_value
# FLIP COUNT: 403, for 1000 attempts, 971 were under p_value
# FLIP COUNT: 404, for 1000 attempts, 972 were under p_value
# FLIP COUNT: 405, for 1000 attempts, 977 were under p_value
# FLIP COUNT: 406, for 1000 attempts, 987 were under p_value
# FLIP COUNT: 407, for 1000 attempts, 982 were under p_value
# FLIP COUNT: 408, for 1000 attempts, 982 were under p_value
# FLIP COUNT: 409, for 1000 attempts, 981 were under p_value
# FLIP COUNT: 410, for 1000 attempts, 981 were under p_value
# FLIP COUNT: 411, for 1000 attempts, 986 were under p_value
# FLIP COUNT: 412, for 1000 attempts, 982 were under p_value
# FLIP COUNT: 413, for 1000 attempts, 980 were under p_value
# FLIP COUNT: 414, for 1000 attempts, 986 were under p_value
# FLIP COUNT: 415, for 1000 attempts, 976 were under p_value
# FLIP COUNT: 416, for 1000 attempts, 981 were under p_value
# FLIP COUNT: 417, for 1000 attempts, 979 were under p_value
# FLIP COUNT: 418, for 1000 attempts, 987 were under p_value
# FLIP COUNT: 419, for 1000 attempts, 987 were under p_value
# FLIP COUNT: 420, for 1000 attempts, 977 were under p_value
# FLIP COUNT: 421, for 1000 attempts, 978 were under p_value
# FLIP COUNT: 422, for 1000 attempts, 985 were under p_value
# FLIP COUNT: 423, for 1000 attempts, 983 were under p_value
# FLIP COUNT: 424, for 1000 attempts, 980 were under p_value
# FLIP COUNT: 425, for 1000 attempts, 976 were under p_value
# FLIP COUNT: 426, for 1000 attempts, 979 were under p_value
# FLIP COUNT: 427, for 1000 attempts, 983 were under p_value
# FLIP COUNT: 428, for 1000 attempts, 987 were under p_value
# FLIP COUNT: 429, for 1000 attempts, 983 were under p_value
# FLIP COUNT: 430, for 1000 attempts, 988 were under p_value
# FLIP COUNT: 431, for 1000 attempts, 983 were under p_value
# FLIP COUNT: 432, for 1000 attempts, 986 were under p_value
# FLIP COUNT: 433, for 1000 attempts, 978 were under p_value
# FLIP COUNT: 434, for 1000 attempts, 986 were under p_value
# FLIP COUNT: 435, for 1000 attempts, 988 were under p_value
# FLIP COUNT: 436, for 1000 attempts, 993 were under p_value
# FLIP COUNT: 437, for 1000 attempts, 988 were under p_value
# FLIP COUNT: 438, for 1000 attempts, 987 were under p_value
# FLIP COUNT: 439, for 1000 attempts, 984 were under p_value
# FLIP COUNT: 440, for 1000 attempts, 984 were under p_value
# FLIP COUNT: 441, for 1000 attempts, 986 were under p_value
# FLIP COUNT: 442, for 1000 attempts, 989 were under p_value
# FLIP COUNT: 443, for 1000 attempts, 987 were under p_value
# FLIP COUNT: 444, for 1000 attempts, 988 were under p_value
# FLIP COUNT: 445, for 1000 attempts, 987 were under p_value
# FLIP COUNT: 446, for 1000 attempts, 981 were under p_value
# FLIP COUNT: 447, for 1000 attempts, 995 were under p_value
# FLIP COUNT: 448, for 1000 attempts, 989 were under p_value
# FLIP COUNT: 449, for 1000 attempts, 991 were under p_value
# FLIP COUNT: 450, for 1000 attempts, 988 were under p_value
# FLIP COUNT: 451, for 1000 attempts, 993 were under p_value
# FLIP COUNT: 452, for 1000 attempts, 989 were under p_value
# FLIP COUNT: 453, for 1000 attempts, 987 were under p_value
# FLIP COUNT: 454, for 1000 attempts, 986 were under p_value
# FLIP COUNT: 455, for 1000 attempts, 992 were under p_value
# FLIP COUNT: 456, for 1000 attempts, 991 were under p_value
# FLIP COUNT: 457, for 1000 attempts, 994 were under p_value
# FLIP COUNT: 458, for 1000 attempts, 994 were under p_value
# FLIP COUNT: 459, for 1000 attempts, 995 were under p_value
# FLIP COUNT: 460, for 1000 attempts, 981 were under p_value
# FLIP COUNT: 461, for 1000 attempts, 991 were under p_value
# FLIP COUNT: 462, for 1000 attempts, 995 were under p_value
# FLIP COUNT: 463, for 1000 attempts, 988 were under p_value
# FLIP COUNT: 464, for 1000 attempts, 993 were under p_value
# FLIP COUNT: 465, for 1000 attempts, 993 were under p_value
# FLIP COUNT: 466, for 1000 attempts, 990 were under p_value
# FLIP COUNT: 467, for 1000 attempts, 990 were under p_value
# FLIP COUNT: 468, for 1000 attempts, 990 were under p_value
# FLIP COUNT: 469, for 1000 attempts, 990 were under p_value
# FLIP COUNT: 470, for 1000 attempts, 990 were under p_value
# FLIP COUNT: 471, for 1000 attempts, 988 were under p_value
# FLIP COUNT: 472, for 1000 attempts, 990 were under p_value
# FLIP COUNT: 473, for 1000 attempts, 996 were under p_value
# FLIP COUNT: 474, for 1000 attempts, 996 were under p_value
# FLIP COUNT: 475, for 1000 attempts, 991 were under p_value
# FLIP COUNT: 476, for 1000 attempts, 986 were under p_value
# FLIP COUNT: 477, for 1000 attempts, 992 were under p_value
# FLIP COUNT: 478, for 1000 attempts, 994 were under p_value
# FLIP COUNT: 479, for 1000 attempts, 992 were under p_value
# FLIP COUNT: 480, for 1000 attempts, 992 were under p_value
# FLIP COUNT: 481, for 1000 attempts, 996 were under p_value
# FLIP COUNT: 482, for 1000 attempts, 990 were under p_value
# FLIP COUNT: 483, for 1000 attempts, 993 were under p_value
# FLIP COUNT: 484, for 1000 attempts, 993 were under p_value
# FLIP COUNT: 485, for 1000 attempts, 987 were under p_value
# FLIP COUNT: 486, for 1000 attempts, 998 were under p_value
# FLIP COUNT: 487, for 1000 attempts, 994 were under p_value
# FLIP COUNT: 488, for 1000 attempts, 993 were under p_value
# FLIP COUNT: 489, for 1000 attempts, 991 were under p_value
# FLIP COUNT: 490, for 1000 attempts, 990 were under p_value
# FLIP COUNT: 491, for 1000 attempts, 996 were under p_value
# FLIP COUNT: 492, for 1000 attempts, 996 were under p_value
# FLIP COUNT: 493, for 1000 attempts, 990 were under p_value
# FLIP COUNT: 494, for 1000 attempts, 992 were under p_value
# FLIP COUNT: 495, for 1000 attempts, 992 were under p_value
# FLIP COUNT: 496, for 1000 attempts, 998 were under p_value
# FLIP COUNT: 497, for 1000 attempts, 997 were under p_value
# FLIP COUNT: 498, for 1000 attempts, 993 were under p_value
# FLIP COUNT: 499, for 1000 attempts, 997 were under p_value
